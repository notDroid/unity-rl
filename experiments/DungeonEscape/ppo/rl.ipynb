# %% [markdown]
# # **DungeonEscapeEnv Reinforcement Learning**

# %%
ENV_PATH = "../../../envs/DungeonEscape"

# %% [markdown]
# ### **Imports**

# %%
### Utility
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tempfile
import time
import os

### Torch
import torch
from torch import nn
from torch import optim

# Model
# from model_util import MLP

### Torch RL
# Env
from torchrl.envs.libs import UnityMLAgentsEnv
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
from torchrl.envs.utils import step_mdp, check_env_specs
from torchrl.envs import TransformedEnv, Stack, ExcludeTransform

# Modules
from tensordict.nn import TensorDictModule
from tensordict.nn.distributions import NormalParamExtractor
from torchrl.modules import ProbabilisticActor, TanhNormal
from torch.distributions import Normal, Independent

# Data Collection
from torchrl.collectors import SyncDataCollector, MultiSyncDataCollector
from torchrl.collectors.utils import split_trajectories
from torchrl.data import LazyTensorStorage, ReplayBuffer
from torchrl.data.replay_buffers.samplers import SamplerWithoutReplacement

# Loss
from torchrl.objectives import ClipPPOLoss, ValueEstimators

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using Device: {device}")
# Out:
# Using Device: cpu

# %% [markdown]
# ## **Create Torch Env**

# %%
def create_unity_env(graphics=False, **kwargs):
    try:
        env.close()
    except:
        pass
    
    env = TransformedEnv(UnityMLAgentsEnv(
        file_name=ENV_PATH, worker_id=np.random.randint(10000), 
        no_graphics=(not graphics), **kwargs,
        device="cpu",
    ))

    return env

def batch_agents(env, out_key="agents"):
    agent_root_key = env.observation_keys[0][0]
    agents = list(env.action_spec[agent_root_key].keys())
    
    # Create transform
    stack = Stack(
        in_keys=[(agent_root_key, agent) for agent in agents], 
        out_key=(out_key,), 
        in_key_inv=(out_key,), 
        out_keys_inv=[(agent_root_key, agent) for agent in agents]
    )

    env.append_transform(stack)
    return env

def create_base_env(graphics=False, **kwargs):
    env = create_unity_env(graphics, **kwargs)
    env = batch_agents(env)
    return env

# %%
def print_specs(env):
    print("action_spec:", env.action_spec)
    print("reward_spec:", env.reward_spec)
    print("done_spec:", env.done_spec)
    print("observation_spec:", env.observation_spec)

env = create_unity_env(graphics=True)
check_env_specs(env)
print_specs(env)
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# 2025-09-27 17:51:10,521 [torchrl][INFO]    check_env_specs succeeded! [END]
# action_spec: Composite(
#     group_1: Composite(
#         agent_0: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_1: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_35: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_3: Composite(
#         agent_2: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_22: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_25: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_2: Composite(
#         agent_3: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_23: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_26: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_4: Composite(
#         agent_4: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_21: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_24: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_5: Composite(
#         agent_5: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_20: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_27: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_7: Composite(
#         agent_6: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_18: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_29: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_6: Composite(
#         agent_7: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_19: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_30: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_8: Composite(
#         agent_8: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_17: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_28: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_9: Composite(
#         agent_9: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_15: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_33: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_10: Composite(
#         agent_10: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_16: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_34: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_12: Composite(
#         agent_11: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_13: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_31: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_11: Composite(
#         agent_12: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_14: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_32: Composite(
#             discrete_action: MultiOneHot(
#                 shape=torch.Size([7]),
#                 space=BoxList(boxes=[CategoricalBox(n=7)]),
#                 device=cpu,
#                 dtype=torch.int32,
#                 domain=discrete),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     device=cpu,
#     shape=torch.Size([]),
#     data_cls=None)
# reward_spec: Composite(
#     group_1: Composite(
#         agent_0: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_1: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_35: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_3: Composite(
#         agent_2: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_22: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_25: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_2: Composite(
#         agent_3: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_23: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_26: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_4: Composite(
#         agent_4: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_21: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_24: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_5: Composite(
#         agent_5: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_20: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_27: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_7: Composite(
#         agent_6: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_18: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_29: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_6: Composite(
#         agent_7: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_19: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_30: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_8: Composite(
#         agent_8: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_17: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_28: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_9: Composite(
#         agent_9: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_15: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_33: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_10: Composite(
#         agent_10: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_16: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_34: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_12: Composite(
#         agent_11: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_13: Composite(
#             reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             group_reward: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
# ...
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_33: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_10: Composite(
#         agent_10: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_16: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_34: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_12: Composite(
#         agent_11: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_13: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_31: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     group_11: Composite(
#         agent_12: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_14: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         agent_32: Composite(
#             RBSensor: UnboundedContinuous(
#                 shape=torch.Size([10]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([10]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             StackingSensor_size3_RayPerceptionSensor: UnboundedContinuous(
#                 shape=torch.Size([360]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([360]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             VectorSensor_size1: UnboundedContinuous(
#                 shape=torch.Size([1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([]),
#         data_cls=None),
#     device=cpu,
#     shape=torch.Size([]),
#     data_cls=None)

# %%
env = create_unity_env(graphics=True)
env.rollout(10_000)
env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
