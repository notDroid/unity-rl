# %% [markdown]
# # **Worm PPO**

# %% [markdown]
# ### **Imports**

# %%
from config import *
from rlkit.util import Checkpointer, Logger, SimpleMetricModule

import pandas as pd
import matplotlib.pyplot as plt
from train_util import *
import matplotlib.pyplot as plt
from env import create_env

# %% [markdown]
# ## **Inspect Environment**

# %%
try: env.close()
except: pass

env = create_env(graphics=False, time_scale=10)
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# Mono path[0] = '/var/folders/l_/gtffst3j133f47568b_fd9zr0000gn/T/ml-agents-binaries/binaries/Worm-0b2d628333f5f2f77e17caa072661a50/Startup/Startup.app/Contents/Resources/Data/Managed'
# Mono config path = '/var/folders/l_/gtffst3j133f47568b_fd9zr0000gn/T/ml-agents-binaries/binaries/Worm-0b2d628333f5f2f77e17caa072661a50/Startup/Startup.app/Contents/MonoBleedingEdge/etc'
# New input system (experimental) initialized
# Initialize engine version: 2022.3.4f1 (35713cd46cd7)
# [Subsystems] Discovering subsystems at path /var/folders/l_/gtffst3j133f47568b_fd9zr0000gn/T/ml-agents-binaries/binaries/Worm-0b2d628333f5f2f77e17caa072661a50/Startup/Startup.app/Contents/Resources/Data/UnitySubsystems
# Forcing GfxDevice: Null
# GfxDevice: creating device client; threaded=0; jobified=0
# NullGfxDevice:
#     Version:  NULL 1.0 [1.0]
#     Renderer: Null Device
#     Vendor:   Unity Technologies
# Begin MonoManager ReloadAssembly
# - Loaded All Assemblies, in  0.167 seconds
# - Finished resetting the current domain, in  0.003 seconds
# ERROR: Shader Sprites/Default shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# ERROR: Shader Sprites/Mask shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# UnloadTime: 1.125959 ms
# Command line arguments passed: /var/folders/l_/gtffst3j133f47568b_fd9zr0000gn/T/ml-agents-binaries/binaries/Worm-0b2d628333f5f2f77e17caa072661a50/Startup/Startup.app/Contents/MacOS/UnityEnvironment -nographics -batchmode --mlagents-port 10070 --mlagents-scene-name Assets/ML-Agents/Examples/Worm/Scenes/Worm.unity
# ERROR: Shader Legacy Shaders/VertexLit shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# WARNING: Shader Unsupported: 'Legacy Shaders/Diffuse' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# ERROR: Shader Legacy Shaders/Diffuse shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# WARNING: Shader Unsupported: 'Legacy Shaders/Diffuse' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# WARNING: Shader Unsupported: 'ML-Agents/GridPattern' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# ERROR: Shader ML-Agents/GridPattern shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# WARNING: Shader Unsupported: 'ML-Agents/GridPattern' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# WARNING: Shader Unsupported: 'Autodesk Interactive' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# ERROR: Shader Autodesk Interactive shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# WARNING: Shader Unsupported: 'Autodesk Interactive' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# WARNING: Shader Unsupported: 'Standard' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# ERROR: Shader Standard shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# WARNING: Shader Unsupported: 'Standard' - All subshaders removed
# WARNING: Shader Did you use #pragma only_renderers and omit this platform?
# WARNING: Shader If subshaders removal was intentional, you may have forgotten turning Fallback off?
# Unloading 7 Unused Serialized files (Serialized files now loaded: 0)
# UnloadTime: 0.218875 ms
# Registered Communicator in Agent.
# Unloading 6 unused Assets to reduce memory usage. Loaded Objects now: 2992.
# Total: 1.139166 ms (FindLiveObjects: 0.097375 ms CreateObjectMapping: 0.016959 ms MarkObjects: 1.002125 ms  DeleteObjects: 0.022583 ms)
# /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/transforms/transforms.py:587: FutureWarning: The key 'continuous_action' is unaccounted for by the transform (expected keys ['VectorSensor_size64', 'done', 'terminated', 'truncated', 'group_reward', 'reward']). Every new entry in the tensordict resulting from a call to a transform must be registered in the specs for torchrl rollouts to be consistently built. Make sure transform_output_spec/transform_observation_spec/... is coded correctly. This warning will trigger a KeyError in v0.9, make sure to adapt your code accordingly.
#   warnings.warn(

# %%
data = env.rollout(1000, break_when_any_done=False)
# Out:
# ERROR: Shader UI/Default shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/libs/unity_mlagents.py:373: DeprecationWarning: In future, it will be an error for 'np.bool' scalars to be interpreted as an index
#   source[group_name][agent_name]["truncated"] = torch.tensor(

# %%
data
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([10, 1000, 9]), device=cpu, dtype=torch.float32, is_shared=False),
#         done: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         next: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([10, 1000, 64]), device=cpu, dtype=torch.float32, is_shared=False),
#                 reward: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([10, 1000]),
#             device=cpu,
#             is_shared=False),
#         observation: Tensor(shape=torch.Size([10, 1000, 64]), device=cpu, dtype=torch.float32, is_shared=False),
#         terminated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([10, 1000]),
#     device=cpu,
#     is_shared=False)

# %%
obs_df = pd.DataFrame(data["observation"].reshape(-1))
act_df = pd.DataFrame(data["action"].reshape(-1))
rew_df = pd.DataFrame(data["next", "reward"].reshape(-1))

for i, df in enumerate([obs_df, act_df, rew_df]):
    plt.violinplot(df, positions=[i], widths=0.9)

# %% [markdown]
# ## **Results**

# %%
def plot(name):
    # Get dataframe
    logger = Logger(keys = LOG_KEYS, log_path=LOG_PATH, name=name)
    logger.revert()
    df = logger.dataframe()
    df = df.set_index(LOG_INDEX)

    # Plot it
    rows = (len(df.columns) + 3) // 4
    df.plot(subplots=True, layout=(rows,4), figsize=(15, int(rows* 7/3)))
    plt.tight_layout()
    plt.savefig(os.path.join(RESULTS_PATH, f"{name}.png"))

# %%
plot(NAME)

# %%
def load_policy_from_model(policy, model_path, name):
    model_params = torch.load(os.path.join(model_path, f"{name}.pt"), map_location="cpu", weights_only=True)
    policy.load_state_dict(model_params["policy_state_dict"])

def load_policy_from_checkpoint(policy, ckpt_path, name, ckpt_type='latest'):
    checkpointer = Checkpointer(ckpt_path=ckpt_path, name=name)
    checkpoint = checkpointer.load_progress()
    checkpoint = torch.load(os.path.join(ckpt_path, f"{name}_{ckpt_type}.ckpt"), map_location="cpu", weights_only=True)
    policy.load_state_dict(checkpoint["policy_state_dict"])

policy = create_policy(MODEL_CONFIG).to(device)
# load_policy_from_model(policy, MODEL_PATH, 'run1')
load_policy_from_checkpoint(policy, CKPT_PATH, NAME, ckpt_type='latest')

# %%
try: env.close()
except: pass

env = create_env(graphics=True, time_scale=10)
env.reset()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/transforms/transforms.py:587: FutureWarning: The key 'continuous_action' is unaccounted for by the transform (expected keys ['VectorSensor_size64', 'done', 'terminated', 'truncated', 'group_reward', 'reward']). Every new entry in the tensordict resulting from a call to a transform must be registered in the specs for torchrl rollouts to be consistently built. Make sure transform_output_spec/transform_observation_spec/... is coded correctly. This warning will trigger a KeyError in v0.9, make sure to adapt your code accordingly.
#   warnings.warn(
# TensorDict(
#     fields={
#         done: Tensor(shape=torch.Size([10, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         observation: Tensor(shape=torch.Size([10, 64]), device=cpu, dtype=torch.float32, is_shared=False),
#         terminated: Tensor(shape=torch.Size([10, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([10, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([10]),
#     device=cpu,
#     is_shared=False)

# %%
data = None
with torch.no_grad():
    data = env.rollout(1000, policy=policy, break_when_any_done=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/walimirza/unity-rl/experiments/Worm/ppo/rl.ipynb Cell 14 line 3
#       <a href='vscode-notebook-cell:/Users/walimirza/unity-rl/experiments/Worm/ppo/rl.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> data = None
#       <a href='vscode-notebook-cell:/Users/walimirza/unity-rl/experiments/Worm/ppo/rl.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> with torch.no_grad():
# ----> <a href='vscode-notebook-cell:/Users/walimirza/unity-rl/experiments/Worm/ppo/rl.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     data = env.rollout(1000, policy=policy, break_when_any_done=False)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/common.py:3384, in EnvBase.rollout(self, max_steps, policy, callback, auto_reset, auto_cast_to_device, break_when_any_done, break_when_all_done, return_contiguous, tensordict, set_truncated, out, trust_policy)
#    3378     tensordicts = self._rollout_stop_early(
#    3379         break_when_all_done=break_when_all_done,
#    3380         break_when_any_done=break_when_any_done,
#    3381         **kwargs,
#    3382     )
#    3383 else:
# -> 3384     tensordicts = self._rollout_nonstop(**kwargs)
#    3385 batch_size = self.batch_size if tensordict is None else tensordict.batch_size
#    3386 if return_contiguous:
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/common.py:3616, in EnvBase._rollout_nonstop(self, tensordict, auto_cast_to_device, max_steps, policy, policy_device, env_device, callback)
#    3614     tensordict = self.step(tensordict_)
#    3615 else:
# -> 3616     tensordict, tensordict_ = self.step_and_maybe_reset(tensordict_)
#    3617 tensordicts.append(tensordict)
#    3618 if i == max_steps - 1:
#    3619     # we don't truncate as one could potentially continue the run
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/common.py:3670, in EnvBase.step_and_maybe_reset(self, tensordict)
#    3668 if tensordict.device != self.device:
#    3669     tensordict = tensordict.to(self.device)
# -> 3670 tensordict = self.step(tensordict)
#    3671 # done and truncated are in done_keys
#    3672 # We read if any key is done.
#    3673 tensordict_ = self._step_mdp(tensordict)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/common.py:2102, in EnvBase.step(self, tensordict)
#    2099 next_preset = tensordict.get("next", None)
#    2101 if next_tensordict is None:
# -> 2102     next_tensordict = self._step(tensordict)
#    2103     next_tensordict = self._step_proc_data(next_tensordict)
#    2104 if next_preset is not None:
#    2105     # tensordict could already have a "next" key
#    2106     # this could be done more efficiently by not excluding but just passing
#    2107     # the necessary keys
#
# File ~/unity-rl/rlkit/src/rlkit/transforms/soft_reset.py:13, in SoftResetWrapper._step(self, tensordict)
#      12 def _step(self, tensordict):
# ---> 13     self._last = self.env._step(tensordict)
#      14     return self._last
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/transforms/transforms.py:1230, in TransformedEnv._step(self, tensordict)
#    1227         tensordict_batch_size = self.batch_size
#    1229 if next_tensordict is None:
# -> 1230     next_tensordict = self.base_env._step(tensordict_in)
#    1231     if next_preset is not None:
#    1232         # tensordict could already have a "next" key
#    1233         # this could be done more efficiently by not excluding but just passing
#    1234         # the necessary keys
#    1235         next_tensordict.update(
#    1236             next_preset.exclude(*next_tensordict.keys(True, True))
#    1237         )
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/torchrl/envs/libs/unity_mlagents.py:479, in UnityMLAgentsWrapper._step(self, tensordict)
#     475             action_tuple.add_continuous(continuous_action[None, ...].numpy())
#     477         self._env.set_action_for_agent(behavior, agent_id, action_tuple)
# --> 479 self._env.step()
#     480 self._update_action_mask()
#     481 return self._make_td_out(tensordict)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/mlagents_envs/timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/mlagents_envs/environment.py:346, in UnityEnvironment.step(self)
#     342             n_agents = len(self._env_state[group_name][0])
#     343         self._env_actions[group_name] = self._env_specs[
#     344             group_name
#     345         ].action_spec.empty_action(n_agents)
# --> 346 step_input = self._generate_step_input(self._env_actions)
#     347 with hierarchical_timer("communicator.exchange"):
#     348     outputs = self._communicator.exchange(step_input, self._poll_process)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/mlagents_envs/timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/mlagents_envs/environment.py:477, in UnityEnvironment._generate_step_input(self, vector_action)
#     473         rl_in.command = STEP
#     474 rl_in.side_channel = bytes(
#     475     self._side_channel_manager.generate_side_channel_messages()
#     476 )
# --> 477 return self._wrap_unity_input(rl_in)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/mlagents_envs/environment.py:497, in UnityEnvironment._wrap_unity_input(rl_input)
#     494 @staticmethod
#     495 def _wrap_unity_input(rl_input: UnityRLInputProto) -> UnityInputProto:
#     496     result = UnityInputProto()
# --> 497     result.rl_input.CopyFrom(rl_input)
#     498     return result
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/message.py:129, in Message.CopyFrom(self, other_msg)
#     127   return
#     128 self.Clear()
# --> 129 self.MergeFrom(other_msg)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/python_message.py:1328, in _AddMergeFromMethod.<locals>.MergeFrom(self, msg)
#    1326     field_value = field._default_constructor(self)
#    1327     fields[field] = field_value
# -> 1328   field_value.MergeFrom(value)
#    1329 elif field.cpp_type == CPPTYPE_MESSAGE:
#    1330   if value._is_present_in_parent:
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/containers.py:569, in MessageMap.MergeFrom(self, other)
#     567 if key in self:
#     568   del self[key]
# --> 569 self[key].CopyFrom(other[key])
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/message.py:129, in Message.CopyFrom(self, other_msg)
#     127   return
#     128 self.Clear()
# --> 129 self.MergeFrom(other_msg)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/python_message.py:1328, in _AddMergeFromMethod.<locals>.MergeFrom(self, msg)
#    1326     field_value = field._default_constructor(self)
#    1327     fields[field] = field_value
# -> 1328   field_value.MergeFrom(value)
#    1329 elif field.cpp_type == CPPTYPE_MESSAGE:
#    1330   if value._is_present_in_parent:
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/containers.py:323, in RepeatedCompositeFieldContainer.MergeFrom(self, other)
#     316 def MergeFrom(
#     317     self,
#     318     other: Union['RepeatedCompositeFieldContainer[_T]', Iterable[_T]],
#     319 ) -> None:
#     320   """Appends the contents of another repeated field of the same type to this
#     321   one, copying each individual message.
#     322   """
# --> 323   self.extend(other)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/containers.py:312, in RepeatedCompositeFieldContainer.extend(self, elem_seq)
#     310   new_element = message_class()
#     311   new_element._SetListener(listener)
# --> 312   new_element.MergeFrom(message)
#     313   values.append(new_element)
#     314 listener.Modified()
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/python_message.py:1326, in _AddMergeFromMethod.<locals>.MergeFrom(self, msg)
#    1323 field_value = fields.get(field)
#    1324 if field_value is None:
#    1325   # Construct a new object to represent this field.
# -> 1326   field_value = field._default_constructor(self)
#    1327   fields[field] = field_value
#    1328 field_value.MergeFrom(value)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/python_message.py:443, in _DefaultValueConstructorForField.<locals>.MakeRepeatedScalarDefault(message)
#     442 def MakeRepeatedScalarDefault(message):
# --> 443   return containers.RepeatedScalarFieldContainer(
#     444       message._listener_for_children, type_checker)
#
# File /opt/homebrew/anaconda3/envs/mlagents3/lib/python3.10/site-packages/google/protobuf/internal/containers.py:145, in RepeatedScalarFieldContainer.__init__(self, message_listener, type_checker)
#     132 def __init__(
#     133     self,
#     134     message_listener: Any,
#     135     type_checker: Any,
#     136 ) -> None:
#     137   """Args:
#     138
#     139     message_listener: A MessageListener implementation. The
#    (...)
#     143     inserted into this container.
#     144   """
# --> 145   super().__init__(message_listener)
#     146   self._type_checker = type_checker
#
# KeyboardInterrupt:

# %%
data
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([10, 1000, 20]), device=cpu, dtype=torch.float32, is_shared=False),
#         done: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         loc: Tensor(shape=torch.Size([10, 1000, 20]), device=cpu, dtype=torch.float32, is_shared=False),
#         log_prob: Tensor(shape=torch.Size([10, 1000]), device=cpu, dtype=torch.float32, is_shared=False),
#         next: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([10, 1000, 158]), device=cpu, dtype=torch.float32, is_shared=False),
#                 reward: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([10, 1000]),
#             device=cpu,
#             is_shared=False),
#         observation: Tensor(shape=torch.Size([10, 1000, 158]), device=cpu, dtype=torch.float32, is_shared=False),
#         scale: Tensor(shape=torch.Size([10, 1000, 20]), device=cpu, dtype=torch.float32, is_shared=False),
#         terminated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([10, 1000, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([10, 1000]),
#     device=cpu,
#     is_shared=False)

# %%
try: env.close()
except: pass

# %%
SimpleMetricModule(mode="approx")(data)
# Out:
# {'return': 342.93914794921875,
#  'episode_length': 1000.0,
#  'entropy': -0.10540435463190079}
